# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df=pd.read_csv('co2.csv')

# %%
df.head()
# Out:
#    engine  cylandr  fuelcomb  out1
# 0     2.0        4       8.5   196
# 1     2.4        4       9.6   221
# 2     1.5        4       5.9   136
# 3     3.5        6      11.1   255
# 4     3.5        6      10.6   244

# %%
df.describe()
# Out:
#            engine     cylandr    fuelcomb        out1
# count  500.000000  500.000000  500.000000  500.000000
# mean     3.600400    6.132000   12.476600  268.026000
# std      1.478191    1.832291    3.943025   67.099673
# min      1.000000    4.000000    4.800000  110.000000
# 25%      2.000000    4.000000    9.500000  217.000000
# 50%      3.600000    6.000000   11.650000  260.000000
# 75%      5.000000    8.000000   14.800000  317.000000
# max      6.800000   12.000000   25.800000  488.000000

# %%
sns.countplot(x='out1',data=df)
# Out:
# <Axes: xlabel='out1', ylabel='count'>

# %%
plt.subplots(figsize=(9,9))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=df.drop('out1',axis=1)
# x=x.drop('fuelcomb',axis=1)
# x=x.drop('cylandr',axis=1)
y=df.out1

# %%
x
# Out:
#      engine  cylandr  fuelcomb
# 0       2.0        4       8.5
# 1       2.4        4       9.6
# 2       1.5        4       5.9
# 3       3.5        6      11.1
# 4       3.5        6      10.6
# ..      ...      ...       ...
# 495     1.5        4       6.9
# 496     1.5        4       7.5
# 497     1.5        4       7.7
# 498     3.5        6      10.6
# 499     3.6        6      10.8
#
# [500 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([332.58597646, 369.84504906, 239.18448001, 267.72013858,
#        299.35637675, 412.86387769, 327.88114631, 266.49009585,
#        210.00832731, 351.13884335, 389.56578933, 346.8026928 ,
#        291.5563278 , 250.51042932, 343.07234067, 316.71942484,
#        307.58710727, 345.30619635, 257.24466338, 186.27972478,
#        250.51042932, 333.33422469, 317.36544718, 191.51746237,
#        329.59298355, 274.82305224, 204.77058971, 242.17747293,
#        361.23474993, 309.14024487, 351.13884335, 378.4553482 ,
#        180.99087423, 345.30619635, 342.90811283, 242.17747293,
#        200.28110034, 343.17456656, 209.84409947, 374.33453843,
#        332.43263763, 229.45725304, 257.24466338, 351.40529707,
#        327.88114631, 376.09748861, 269.21663504, 248.91170698,
#        353.53692686, 368.40502635, 257.24466338, 296.46560972,
#        230.20550127, 275.68441537, 336.92212701, 201.77759679,
#        213.31888689, 195.04336274, 336.92212701, 260.7194508 ,
#        211.50482376, 261.73415275, 274.72082636, 361.23474993,
#        346.8026928 , 297.91652144, 312.38327429, 251.15645167,
#        321.90604949, 234.69499064, 351.13884335, 192.79861805,
#        202.52584502, 265.47539389, 251.15645167, 252.00692578,
#        227.96075658, 277.44736555, 249.7621811 , 296.90181949,
#        293.52925796, 255.4817132 , 309.14024487, 385.1274129 ,
#        257.99291161, 357.82196446, 281.18860669, 254.14944458,
#        189.96985298, 357.82196446, 198.25169643, 316.71942484,
#        213.74956845, 267.72013858, 328.09648709, 351.13884335,
#        307.58710727, 351.13884335, 175.58890879, 316.71942484])

# %%
y_test
# Out:
# 473    338
# 212    334
# 94     221
# 187    290
# 106    292
#       ...
# 264    294
# 125    317
# 268    294
# 415    126
# 263    317
# Name: out1, Length: 100, dtype: int64

# %%
plt.scatter(x_test.engine,y_test,color='blue')
plt.scatter(x_test.fuelcomb,y_test,color='red')
plt.scatter(x_test.cylandr,y_test,color='green')

# plt.plot(x_test,y_pred,color='red',linewidth=2)
plt.show()

# %%
p206=np.array([[5.2,10,4]])

# %%
co2=model.predict(p206)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
co2
# Out:
# array([265.14677082])

# %%
sm.mean_squared_error(y_test,y_pred)
# Out:
# 973.6041642339562
